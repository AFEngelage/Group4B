# %%
import pandas as pd
import altair as alt
import numpy as np
import seaborn as sns

file_path_oil = r'C:\Users\sebas\OneDrive\Documenten\GitHub\Supermarketcasegroupproject\Group4B\data\raw\oil.parquet'
df_oil = pd.read_parquet(file_path_oil)

df_oil.describe()
df_oilnull = df_oil.isnull().sum()

df_oil.info()

df_oilnull
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB
# date           0
# dcoilwtico    43
# dtype: int64

# %%
df_oil[df_oil['dcoilwtico'].isnull()]
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 14    2013-01-21         NaN
# 34    2013-02-18         NaN
# 63    2013-03-29         NaN
# 104   2013-05-27         NaN
# 132   2013-07-04         NaN
# 174   2013-09-02         NaN
# 237   2013-11-28         NaN
# 256   2013-12-25         NaN
# 261   2014-01-01         NaN
# 274   2014-01-20         NaN
# 294   2014-02-17         NaN
# 338   2014-04-18         NaN
# 364   2014-05-26         NaN
# 393   2014-07-04         NaN
# 434   2014-09-01         NaN
# 497   2014-11-27         NaN
# 517   2014-12-25         NaN
# 522   2015-01-01         NaN
# 534   2015-01-19         NaN
# 554   2015-02-16         NaN
# 588   2015-04-03         NaN
# 624   2015-05-25         NaN
# 653   2015-07-03         NaN
# 699   2015-09-07         NaN
# 757   2015-11-26         NaN
# 778   2015-12-25         NaN
# 783   2016-01-01         NaN
# 794   2016-01-18         NaN
# 814   2016-02-15         NaN
# 843   2016-03-25         NaN
# ...

# %%
sns.lineplot(data=df_oil, x='date', y='dcoilwtico')

df_oil.plot.line(x='date', y='dcoilwtico', figsize=(10, 6))
# Out:
# <Axes: xlabel='date'>

# %%
df_oiladjusted = df_oil.fillna(method='ffill')

df_oiladjusted.plot.line(x='date', y='dcoilwtico', figsize=(10, 6))
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_18552\4267723574.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_oiladjusted = df_oil.fillna(method='ffill')
# <Axes: xlabel='date'>

# %%
df_oiladjusted[df_oiladjusted['dcoilwtico'].isnull()]
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN

# %%
df_oiladjusted = df_oiladjusted.iloc[1:]

df_oiladjusted[df_oiladjusted['dcoilwtico'].isnull()]
# Out:
#             date  dcoilwtico
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# 5     2013-01-08       93.21
# 6     2013-01-09       93.08
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1216 rows x 2 columns]
