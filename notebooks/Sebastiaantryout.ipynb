# %%
import pandas as pd

file_path_stores = r'C:\Users\sebas\OneDrive\Documenten\GitHub\Supermarketcasegroupproject\Group4B\data\raw\stores.parquet'
df_stores = pd.read_parquet(file_path_stores)

file_path_citiescoordinates = r'C:\Users\sebas\OneDrive\Documenten\GitHub\Supermarketcasegroupproject\Group4B\data\external\ecuadorcities.csv'
df_citiescoordinates = pd.read_csv(file_path_citiescoordinates)

df_citiescoordinates['city'] = df_citiescoordinates['city'].replace("Santo Domingo de los Colorados", "Santo Domingo")

# Display the first few rows of the DataFrame
df_stores.head()

# Display the first few rows of the DataFrame
df_citiescoordinates.head()

merged_df = df_stores.merge(df_citiescoordinates[['city', 'lat', 'lng']], on='city', how='inner')

merged_df
# Out:
#     store_nbr           city                           state type  cluster  \
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# 11         12      Latacunga                        Cotopaxi    C       15
# 12         13      Latacunga                        Cotopaxi    C       15
# 13         14       Riobamba                      Chimborazo    C        7
# 14         15         Ibarra                        Imbabura    C       15
# 15         16  Santo Domingo  Santo Domingo de los Tsachilas    C        3
# 16         17          Quito                       Pichincha    C       12
# 17         18          Quito                       Pichincha    B       16
# 18         19       Guaranda                         Bolivar    C       15
# 19         20          Quito                       Pichincha    B        6
# 20         21  Santo Domingo  Santo Domingo de los Tsachilas    B        6
# 21         22           Puyo                         Pastaza    C        7
# 22         23         Ambato                      Tungurahua    D        9
# 23         24      Guayaquil                          Guayas    D        1
# 24         25        Salinas                     Santa Elena    D        1
# 25         26      Guayaquil                          Guayas    D       10
# 26         27          Daule                          Guayas    D        1
# 27         28      Guayaquil                          Guayas    E       10
# 28         29      Guayaquil                          Guayas    E       10
# 29         30      Guayaquil                          Guayas    C        3
# 30         31       Babahoyo                        Los Rios    B       10
# 31         32      Guayaquil                          Guayas    C        3
# 32         33        Quevedo                        Los Rios    C        3
# 33         34      Guayaquil                          Guayas    B        6
# 34         35         Playas                          Guayas    C        3
# 35         36       Libertad                          Guayas    E       10
# 36         37         Cuenca                           Azuay    D        2
# 37         38           Loja                            Loja    D        4
# 38         39         Cuenca                           Azuay    B        6
# 39         40        Machala                          El Oro    C        3
# 40         41        Machala                          El Oro    D        4
# 41         42         Cuenca                           Azuay    D        2
# 42         43     Esmeraldas                      Esmeraldas    E       10
# 43         44          Quito                       Pichincha    A        5
# 44         45          Quito                       Pichincha    A       11
# 45         46          Quito                       Pichincha    A       14
# 46         47          Quito                       Pichincha    A       14
# 47         48          Quito                       Pichincha    A       14
# 48         49          Quito                       Pichincha    A       11
# 49         50         Ambato                      Tungurahua    A       14
# 50         51      Guayaquil                          Guayas    A       17
# 51         52          Manta                          Manabi    A       11
# 52         53          Manta                          Manabi    D       13
#
#         lat       lng
# 0  -0.22000 -78.51250
# 1  -0.22000 -78.51250
# 2  -0.22000 -78.51250
# 3  -0.22000 -78.51250
# 4  -0.25420 -79.17190
# 5  -0.22000 -78.51250
# 6  -0.22000 -78.51250
# 7  -0.22000 -78.51250
# 8  -0.22000 -78.51250
# 9  -0.22000 -78.51250
# 10  0.04084 -78.14524
# 11 -0.93190 -78.61610
# 12 -0.93190 -78.61610
# 13 -1.67310 -78.64830
# 14  0.36270 -78.13070
# 15 -0.25420 -79.17190
# 16 -0.22000 -78.51250
# 17 -0.22000 -78.51250
# 18 -1.60000 -79.00000
# 19 -0.22000 -78.51250
# 20 -0.25420 -79.17190
# 21 -1.48610 -78.00280
# 22 -1.24170 -78.61970
# 23 -2.19000 -79.88750
# 24 -2.21670 -80.95010
# 25 -2.19000 -79.88750
# 26 -1.86670 -79.98330
# 27 -2.19000 -79.88750
# 28 -2.19000 -79.88750
# 29 -2.19000 -79.88750
# 30 -1.81670 -79.51670
# 31 -2.19000 -79.88750
# 32 -1.03330 -79.45000
# 33 -2.19000 -79.88750
# 34 -2.63199 -80.38808
# 35 -2.23330 -80.91039
# 36 -2.89740 -79.00450
# 37 -3.98330 -79.20000
# 38 -2.89740 -79.00450
# 39 -3.26670 -79.96670
# 40 -3.26670 -79.96670
# 41 -2.89740 -79.00450
# 42  0.96670 -79.65280
# 43 -0.22000 -78.51250
# 44 -0.22000 -78.51250
# 45 -0.22000 -78.51250
# 46 -0.22000 -78.51250
# 47 -0.22000 -78.51250
# 48 -0.22000 -78.51250
# 49 -1.24170 -78.61970
# 50 -2.19000 -79.88750
# 51 -0.95000 -80.71620
# 52 -0.95000 -80.71620

# %%
import plotly.express as px

fig = px.sunburst(df_stores, path=['state', 'city', 'type'], values='store_nbr')
fig.show()

# %%
import folium

# Create a map centered around Ecuador
map_ecuador = folium.Map(location=[-1.8312, -78.1834], zoom_start=7)

# Add markers for each coordinate
# The for loop iterates over the rows of the DataFrame
# The iterrows() method returns an iterator that yields pairs of index and row data as Series
# The row data is a Series that contains the data of the row
# The index is the index of the row
for index, row in merged_df.iterrows():
    folium.Marker([row['lat'], row['lng']], popup=row['city']).add_to(map_ecuador)


# Display the map
map_ecuador

#plotlib
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6014febf6fd5dfdddff69c42757c2cab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6014febf6fd5dfdddff69c42757c2cab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6014febf6fd5dfdddff69c42757c2cab = L.map(
#                 &quot;map_6014febf6fd5dfdddff69c42757c2cab&quot;,
#                 {
#                     center: [-1.8312, -78.1834],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_770e75cd349b0a6af67aa99b04c10251 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_770e75cd349b0a6af67aa99b04c10251.addTo(map_6014febf6fd5dfdddff69c42757c2cab);
#
#
#             var marker_d10136cbd4c0a9984c7c1359f81a3b8b = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_6014febf6fd5dfdddff69c42757c2cab);
#
#
#         var popup_412f10b1bb222d1b4d0026923ea6f2d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cfcd2a48f796da9e7ea3463a8dbca129 = $(`&lt;div id=&quot;html_cfcd2a48f796da9e7ea3463a8dbca129&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_412f10b1bb222d1b4d0026923ea6f2d8.setContent(html_cfcd2a48f796da9e7ea3463a8dbca129);
#
#
#
#         marker_d10136cbd4c0a9984c7c1359f81a3b8b.bindPopup(popup_412f10b1bb222d1b4d0026923ea6f2d8)
#         ;
#
#
#
#
#             var marker_4a34572e1c21e46bc4a96604d8c27567 = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_6014febf6fd5dfdddff69c42757c2cab);
#
#
#         var popup_76b0db80eb1c5178d0863825eb67dca8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4134f4a691d4a2dc56d2a27ecb708e60 = $(`&lt;div id=&quot;html_4134f4a691d4a2dc56d2a27ecb708e60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_76b0db80eb1c5178d0863825eb67dca8.setContent(html_4134f4a691d4a2dc56d2a27ecb708e60);
#
#
#
#         marker_4a34572e1c21e46bc4a96604d8c27567.bindPopup(popup_76b0db80eb1c5178d0863825eb67dca8)
#         ;
#
#
#
#
#             var marker_eed519aadbcf4a0c9b9085215f67ffe9 = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_6014febf6fd5dfdddff69c42757c2cab);
#
#
#         var popup_e8b4a42ca012ba497a04f21e1942b50b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bcea0d5f507f705a2b66e2d1a919b57b = $(`&lt;div id=&quot;html_bcea0d5f507f705a2b66e2d1a919b57b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_e8b4a42ca012ba497a04f21e1942b50b.setContent(html_bcea0d5f507f705a2b66e2d1a919b57b);
#
#
#
#         marker_eed519aadbcf4a0c9b9085215f67ffe9.bindPopup(popup_e8b4a42ca012ba497a04f21e1942b50b)
#         ;
#
#
#
#
#             var marker_f9ad78f02285538500a80e7a0a81dd51 = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_6014febf6fd5dfdddff69c42757c2cab);
#
#
#         var popup_04d74d7936989948100e7000265f6119 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5943753b06167a2e59dcc1371d460a55 = $(`&lt;div id=&quot;html_5943753b06167a2e59dcc1371d460a55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_04d74d7936989948100e7000265f6119.setContent(html_5943753b06167a2e59dcc1371d460a55);
#
#
#
#         marker_f9ad78f02285538500a80e7a0a81dd51.bindPopup(popup_04d74d7936989948100e7000265f6119)
#         ;
#
#
#
#
#             var marker_5e0e16aef3788775439de7d51a03b7f6 = L.marker(
#                 [-0.2542, -79.1719],
#                 {}
#             ).addTo(map_6014febf6fd5dfdddff69c42757c2cab);
#
#
#         var popup_008bbf1189cbe78d787d0fb3eb7b0283 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_15e175b37466bb407e1ae918ab2094f5 = $(`&lt;div id=&quot;html_15e175b37466bb407e1ae918ab2094f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santo Domingo&lt;/div&gt;`)[0];
#                 popup_008bbf1189cbe78d787d0fb3eb7b0283.setContent(html_15e175b37466bb407e1ae918ab2094f5);
#
#
#
#         marker_5e0e16aef3788775439de7d51a03b7f6.bindPopup(popup_008bbf1189cbe78d787d0fb3eb7b0283)
#         ;
#
#
#
#
#             var marker_e8a1f01edc16453da633e3966bb9496d = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_6014febf6fd5dfdddff69c42757c2cab);
#
#
#         var popup_a31a4d7215b33cab12e66c5d13ed9b16 = L.p

# %%
#Altair
#Plotlib

# %%
import folium

# Create a map centered around Ecuador
map_ecuador = folium.Map(location=[-1.8312, -78.1834], zoom_start=7)

# Add markers for each coordinate
# The for loop iterates over the rows of the DataFrame
# The iterrows() method returns an iterator that yields pairs of index and row data as Series
# The row data is a Series that contains the data of the row
# The index is the index of the row
for index, row in merged_df.iterrows():
    folium.Marker(
        [row['lat'], row['lng']], 
        popup=row['city']
        ).add_to(map_ecuador)


# Display the map
map_ecuador
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c6547494cf7d9b33d29d5edf68d4a2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c6547494cf7d9b33d29d5edf68d4a2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c6547494cf7d9b33d29d5edf68d4a2c = L.map(
#                 &quot;map_5c6547494cf7d9b33d29d5edf68d4a2c&quot;,
#                 {
#                     center: [-1.8312, -78.1834],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0372dc80ccdfdcb453148d8796fbd94 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c0372dc80ccdfdcb453148d8796fbd94.addTo(map_5c6547494cf7d9b33d29d5edf68d4a2c);
#
#
#             var marker_c8a0ec0a6d2b5b52f998bf33e9c4c94d = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_5c6547494cf7d9b33d29d5edf68d4a2c);
#
#
#         var popup_70132143eda72a88e8c21a99ce6b6fdc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_382b4224b4fa38282e04a8aa07952cad = $(`&lt;div id=&quot;html_382b4224b4fa38282e04a8aa07952cad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_70132143eda72a88e8c21a99ce6b6fdc.setContent(html_382b4224b4fa38282e04a8aa07952cad);
#
#
#
#         marker_c8a0ec0a6d2b5b52f998bf33e9c4c94d.bindPopup(popup_70132143eda72a88e8c21a99ce6b6fdc)
#         ;
#
#
#
#
#             var marker_6d9983a7a8b2dbd15e0b2154a065bd9b = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_5c6547494cf7d9b33d29d5edf68d4a2c);
#
#
#         var popup_bd394194478706f4a411334f0738c959 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a91565b966b26d92d9cbb971a0a76dc = $(`&lt;div id=&quot;html_1a91565b966b26d92d9cbb971a0a76dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_bd394194478706f4a411334f0738c959.setContent(html_1a91565b966b26d92d9cbb971a0a76dc);
#
#
#
#         marker_6d9983a7a8b2dbd15e0b2154a065bd9b.bindPopup(popup_bd394194478706f4a411334f0738c959)
#         ;
#
#
#
#
#             var marker_e3d93ff779ba54ce72cc8d1028a864f9 = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_5c6547494cf7d9b33d29d5edf68d4a2c);
#
#
#         var popup_9141f63f1d0c64c65fc4c2067b9af820 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ac9152d142c595c25b7d11f23e3fe84 = $(`&lt;div id=&quot;html_1ac9152d142c595c25b7d11f23e3fe84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_9141f63f1d0c64c65fc4c2067b9af820.setContent(html_1ac9152d142c595c25b7d11f23e3fe84);
#
#
#
#         marker_e3d93ff779ba54ce72cc8d1028a864f9.bindPopup(popup_9141f63f1d0c64c65fc4c2067b9af820)
#         ;
#
#
#
#
#             var marker_1a572d6be79dc4d4ba8c74994b29e0a4 = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_5c6547494cf7d9b33d29d5edf68d4a2c);
#
#
#         var popup_30a894fa44b9b018115edc1f75742116 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_529faef30ee1f24c40be76aaf6adbcd6 = $(`&lt;div id=&quot;html_529faef30ee1f24c40be76aaf6adbcd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_30a894fa44b9b018115edc1f75742116.setContent(html_529faef30ee1f24c40be76aaf6adbcd6);
#
#
#
#         marker_1a572d6be79dc4d4ba8c74994b29e0a4.bindPopup(popup_30a894fa44b9b018115edc1f75742116)
#         ;
#
#
#
#
#             var marker_d8edc8f5dcd2942d10cfd3cdba4b0d1e = L.marker(
#                 [-0.2542, -79.1719],
#                 {}
#             ).addTo(map_5c6547494cf7d9b33d29d5edf68d4a2c);
#
#
#         var popup_b9082089af1dbfbe248f340870573736 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53908e48f4c175b5a82bf960acf625e2 = $(`&lt;div id=&quot;html_53908e48f4c175b5a82bf960acf625e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santo Domingo&lt;/div&gt;`)[0];
#                 popup_b9082089af1dbfbe248f340870573736.setContent(html_53908e48f4c175b5a82bf960acf625e2);
#
#
#
#         marker_d8edc8f5dcd2942d10cfd3cdba4b0d1e.bindPopup(popup_b9082089af1dbfbe248f340870573736)
#         ;
#
#
#
#
#             var marker_0eb91abac57f833a38fa03e88aa33e33 = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_5c6547494cf7d9b33d29d5edf68d4a2c);
#
#
#         var popup_dca52eef369509825d56fabd650a5993 = L.p
