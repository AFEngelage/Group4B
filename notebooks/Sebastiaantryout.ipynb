# %%
import pandas as pd
import altair as alt

file_path_stores = r'C:\Users\sebas\OneDrive\Documenten\GitHub\Supermarketcasegroupproject\Group4B\data\raw\stores.parquet'
df_stores = pd.read_parquet(file_path_stores)

file_path_citiescoordinates = r'C:\Users\sebas\OneDrive\Documenten\GitHub\Supermarketcasegroupproject\Group4B\data\external\ecuadorcities.csv'
df_citiescoordinates = pd.read_csv(file_path_citiescoordinates)

df_citiescoordinates['city'] = df_citiescoordinates['city'].replace("Santo Domingo de los Colorados", "Santo Domingo")

# Display the first few rows of the DataFrame
df_stores.head()

# Display the first few rows of the DataFrame
df_citiescoordinates.head()

merged_df = df_stores.merge(df_citiescoordinates[['city', 'lat', 'lng']], on='city', how='inner')

df_stores
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# 11         12      Latacunga                        Cotopaxi    C       15
# 12         13      Latacunga                        Cotopaxi    C       15
# 13         14       Riobamba                      Chimborazo    C        7
# 14         15         Ibarra                        Imbabura    C       15
# 15         16  Santo Domingo  Santo Domingo de los Tsachilas    C        3
# 16         17          Quito                       Pichincha    C       12
# 17         18          Quito                       Pichincha    B       16
# 18         19       Guaranda                         Bolivar    C       15
# 19         20          Quito                       Pichincha    B        6
# 20         21  Santo Domingo  Santo Domingo de los Tsachilas    B        6
# 21         22           Puyo                         Pastaza    C        7
# 22         23         Ambato                      Tungurahua    D        9
# 23         24      Guayaquil                          Guayas    D        1
# 24         25        Salinas                     Santa Elena    D        1
# 25         26      Guayaquil                          Guayas    D       10
# 26         27          Daule                          Guayas    D        1
# 27         28      Guayaquil                          Guayas    E       10
# 28         29      Guayaquil                          Guayas    E       10
# 29         30      Guayaquil                          Guayas    C        3
# 30         31       Babahoyo                        Los Rios    B       10
# 31         32      Guayaquil                          Guayas    C        3
# 32         33        Quevedo                        Los Rios    C        3
# 33         34      Guayaquil                          Guayas    B        6
# 34         35         Playas                          Guayas    C        3
# 35         36       Libertad                          Guayas    E       10
# 36         37         Cuenca                           Azuay    D        2
# 37         38           Loja                            Loja    D        4
# 38         39         Cuenca                           Azuay    B        6
# 39         40        Machala                          El Oro    C        3
# 40         41        Machala                          El Oro    D        4
# 41         42         Cuenca                           Azuay    D        2
# 42         43     Esmeraldas                      Esmeraldas    E       10
# 43         44          Quito                       Pichincha    A        5
# 44         45          Quito                       Pichincha    A       11
# 45         46          Quito                       Pichincha    A       14
# 46         47          Quito                       Pichincha    A       14
# 47         48          Quito                       Pichincha    A       14
# 48         49          Quito                       Pichincha    A       11
# 49         50         Ambato                      Tungurahua    A       14
# 50         51      Guayaquil                          Guayas    A       17
# 51         52          Manta                          Manabi    A       11
# 52         53          Manta                          Manabi    D       13
# 53         54      El Carmen                          Manabi    C        3

# %%
df_stores_groupedtest = df_stores.groupby(['city']).count()

df_stores_groupedtest
# Out:
#                store_nbr  state  type  cluster
# city
# Ambato                 2      2     2        2
# Babahoyo               1      1     1        1
# Cayambe                1      1     1        1
# Cuenca                 3      3     3        3
# Daule                  1      1     1        1
# El Carmen              1      1     1        1
# Esmeraldas             1      1     1        1
# Guaranda               1      1     1        1
# Guayaquil              8      8     8        8
# Ibarra                 1      1     1        1
# Latacunga              2      2     2        2
# Libertad               1      1     1        1
# Loja                   1      1     1        1
# Machala                2      2     2        2
# Manta                  2      2     2        2
# Playas                 1      1     1        1
# Puyo                   1      1     1        1
# Quevedo                1      1     1        1
# Quito                 18     18    18       18
# Riobamba               1      1     1        1
# Salinas                1      1     1        1
# Santo Domingo          3      3     3        3

# %%
df_stores_grouped = df_stores.groupby('city').count().reset_index()
df_stores_grouped.loc[:, ['city', 'store_nbr']]

barchartstorecitycount = alt.Chart(df_stores_grouped).mark_bar().encode(
    x='store_nbr',
    y='city',
)
barchartstorecitycountlabels = barchartstorecitycount.mark_text(
    align= 'left',
    baseline='middle',
    dx=3
).encode(
    text='store_nbr'
)

barchartstorecitycount + barchartstorecitycountlabels
# Out:
# c:\Users\sebas\OneDrive\Documenten\GitHub\Supermarketcasegroupproject\Group4B\.venv\lib\site-packages\altair\utils\core.py:410: FutureWarning:
#
# the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
# alt.LayerChart(...)

# %%
import plotly.express as px

Storessunburst1 = px.sunburst(df_stores, path=['state', 'city', 'type'], values='store_nbr')
Storessunburst1 = px.sunburst(df_stores, path=['state', 'city', 'type'], values='store_nbr')
Storessunburst1 = px.sunburst(df_stores, path=['state', 'city', 'type'], values='store_nbr')





Storessunburst1.show()

# %%
import plotly.express as px

fig = px.treemap(df_stores, path=['state', 'city', 'type'], values='store_nbr', color_continuous_scale= 'rdbu')
fig.show()

# %%
import folium

# Create a map centered around Ecuador
map_ecuador = folium.Map(location=[-1.8312, -78.1834], zoom_start=7)

# Add markers for each coordinate
# The for loop iterates over the rows of the DataFrame
# The iterrows() method returns an iterator that yields pairs of index and row data as Series
# The row data is a Series that contains the data of the row
# The index is the index of the row
for index, row in merged_df.iterrows():
    folium.Marker([row['lat'], row['lng']], popup=row['city']).add_to(map_ecuador)


# Display the map
map_ecuador

#plotlib
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b98ed704655c21ee6e82d3e7d597862 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b98ed704655c21ee6e82d3e7d597862&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b98ed704655c21ee6e82d3e7d597862 = L.map(
#                 &quot;map_1b98ed704655c21ee6e82d3e7d597862&quot;,
#                 {
#                     center: [-1.8312, -78.1834],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30cff68b78d330b8f5f601c162be77a7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_30cff68b78d330b8f5f601c162be77a7.addTo(map_1b98ed704655c21ee6e82d3e7d597862);
#
#
#             var marker_51f9993b13ca294e83eac4d436889070 = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_1b98ed704655c21ee6e82d3e7d597862);
#
#
#         var popup_5820703c49dc353a9e620c0cb8e142fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_405b42cff9abb55410c9c5cf867a5c41 = $(`&lt;div id=&quot;html_405b42cff9abb55410c9c5cf867a5c41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_5820703c49dc353a9e620c0cb8e142fa.setContent(html_405b42cff9abb55410c9c5cf867a5c41);
#
#
#
#         marker_51f9993b13ca294e83eac4d436889070.bindPopup(popup_5820703c49dc353a9e620c0cb8e142fa)
#         ;
#
#
#
#
#             var marker_4c660881bbb8f4ee2f803f5055064832 = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_1b98ed704655c21ee6e82d3e7d597862);
#
#
#         var popup_8de5783d65eadea8fb54435c04e293a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd7490119ae86d3aa89c7fe1ec3becfb = $(`&lt;div id=&quot;html_cd7490119ae86d3aa89c7fe1ec3becfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_8de5783d65eadea8fb54435c04e293a1.setContent(html_cd7490119ae86d3aa89c7fe1ec3becfb);
#
#
#
#         marker_4c660881bbb8f4ee2f803f5055064832.bindPopup(popup_8de5783d65eadea8fb54435c04e293a1)
#         ;
#
#
#
#
#             var marker_ae3113c2d3989961a8b7ab4ccb31d6a1 = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_1b98ed704655c21ee6e82d3e7d597862);
#
#
#         var popup_86e4f248e7536f29fb3f8cd5417794b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0da00a225cda9742a52becb4dad4eac = $(`&lt;div id=&quot;html_a0da00a225cda9742a52becb4dad4eac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_86e4f248e7536f29fb3f8cd5417794b0.setContent(html_a0da00a225cda9742a52becb4dad4eac);
#
#
#
#         marker_ae3113c2d3989961a8b7ab4ccb31d6a1.bindPopup(popup_86e4f248e7536f29fb3f8cd5417794b0)
#         ;
#
#
#
#
#             var marker_4aeef755f73f028f197c910099b84e7e = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_1b98ed704655c21ee6e82d3e7d597862);
#
#
#         var popup_8c22fb19997e8c216b1fb0dc8133c2a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_203fb1549b7d391d24f76a99dda99120 = $(`&lt;div id=&quot;html_203fb1549b7d391d24f76a99dda99120&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_8c22fb19997e8c216b1fb0dc8133c2a4.setContent(html_203fb1549b7d391d24f76a99dda99120);
#
#
#
#         marker_4aeef755f73f028f197c910099b84e7e.bindPopup(popup_8c22fb19997e8c216b1fb0dc8133c2a4)
#         ;
#
#
#
#
#             var marker_1f036477ecd84ea43c2e2b843651cb6d = L.marker(
#                 [-0.2542, -79.1719],
#                 {}
#             ).addTo(map_1b98ed704655c21ee6e82d3e7d597862);
#
#
#         var popup_5fbb87e28f3093b68e5864e0e495ea04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c85c1be4df762159a3b9f4f9c7f915d = $(`&lt;div id=&quot;html_7c85c1be4df762159a3b9f4f9c7f915d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santo Domingo&lt;/div&gt;`)[0];
#                 popup_5fbb87e28f3093b68e5864e0e495ea04.setContent(html_7c85c1be4df762159a3b9f4f9c7f915d);
#
#
#
#         marker_1f036477ecd84ea43c2e2b843651cb6d.bindPopup(popup_5fbb87e28f3093b68e5864e0e495ea04)
#         ;
#
#
#
#
#             var marker_941e28a644ae35ea5be7efeaf6b71c65 = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_1b98ed704655c21ee6e82d3e7d597862);
#
#
#         var popup_c32349a897c78ad5191b3fa3b9412df2 = L.p

# %%
#Altair
#Plotlib

# %%
import folium

# Create a map centered around Ecuador
map_ecuador = folium.Map(location=[-1.8312, -78.1834], zoom_start=7)

# Add markers for each coordinate
# The for loop iterates over the rows of the DataFrame
# The iterrows() method returns an iterator that yields pairs of index and row data as Series
# The row data is a Series that contains the data of the row
# The index is the index of the row
for index, row in merged_df.iterrows():
    folium.Marker(
        [row['lat'], row['lng']], 
        popup=row['city']
        ).add_to(map_ecuador)


# Display the map
map_ecuador
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36613f96a9d2bc2a14cf82ba1b4ca997 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36613f96a9d2bc2a14cf82ba1b4ca997&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36613f96a9d2bc2a14cf82ba1b4ca997 = L.map(
#                 &quot;map_36613f96a9d2bc2a14cf82ba1b4ca997&quot;,
#                 {
#                     center: [-1.8312, -78.1834],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8662fd9b94f45d394e56e54bf90b5523 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8662fd9b94f45d394e56e54bf90b5523.addTo(map_36613f96a9d2bc2a14cf82ba1b4ca997);
#
#
#             var marker_ab98344d848002ef0fbc5e86e225100a = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_36613f96a9d2bc2a14cf82ba1b4ca997);
#
#
#         var popup_96fd0513408c941e508c6c6430622b20 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58f41b0bc68112d4e48f4a3284de9369 = $(`&lt;div id=&quot;html_58f41b0bc68112d4e48f4a3284de9369&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_96fd0513408c941e508c6c6430622b20.setContent(html_58f41b0bc68112d4e48f4a3284de9369);
#
#
#
#         marker_ab98344d848002ef0fbc5e86e225100a.bindPopup(popup_96fd0513408c941e508c6c6430622b20)
#         ;
#
#
#
#
#             var marker_1d6ae04883d869d1d3c64df9df29ffec = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_36613f96a9d2bc2a14cf82ba1b4ca997);
#
#
#         var popup_65eaacc04aa8ff9e7e1be71687197dc0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b45f5a8759eed64b3e790c009da4c0ca = $(`&lt;div id=&quot;html_b45f5a8759eed64b3e790c009da4c0ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_65eaacc04aa8ff9e7e1be71687197dc0.setContent(html_b45f5a8759eed64b3e790c009da4c0ca);
#
#
#
#         marker_1d6ae04883d869d1d3c64df9df29ffec.bindPopup(popup_65eaacc04aa8ff9e7e1be71687197dc0)
#         ;
#
#
#
#
#             var marker_bc470aefbd6a3be8753d7677c3f7a17a = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_36613f96a9d2bc2a14cf82ba1b4ca997);
#
#
#         var popup_8b88e1503a912cb45a8322587191318a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c35bcf320d74d89dae59bf2afa26e63 = $(`&lt;div id=&quot;html_3c35bcf320d74d89dae59bf2afa26e63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_8b88e1503a912cb45a8322587191318a.setContent(html_3c35bcf320d74d89dae59bf2afa26e63);
#
#
#
#         marker_bc470aefbd6a3be8753d7677c3f7a17a.bindPopup(popup_8b88e1503a912cb45a8322587191318a)
#         ;
#
#
#
#
#             var marker_b85b1dabc5048c5f03615e097c4a6edb = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_36613f96a9d2bc2a14cf82ba1b4ca997);
#
#
#         var popup_543393406073ff32e8454a24241d2712 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89da82dab46e1c00a9af8d2573a3a2c3 = $(`&lt;div id=&quot;html_89da82dab46e1c00a9af8d2573a3a2c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Quito&lt;/div&gt;`)[0];
#                 popup_543393406073ff32e8454a24241d2712.setContent(html_89da82dab46e1c00a9af8d2573a3a2c3);
#
#
#
#         marker_b85b1dabc5048c5f03615e097c4a6edb.bindPopup(popup_543393406073ff32e8454a24241d2712)
#         ;
#
#
#
#
#             var marker_599873212efecd3b05ed2687caa010cc = L.marker(
#                 [-0.2542, -79.1719],
#                 {}
#             ).addTo(map_36613f96a9d2bc2a14cf82ba1b4ca997);
#
#
#         var popup_ade876f984418285e719a12682303f64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c46d9f92f3115ddf1985f7fded9041f9 = $(`&lt;div id=&quot;html_c46d9f92f3115ddf1985f7fded9041f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santo Domingo&lt;/div&gt;`)[0];
#                 popup_ade876f984418285e719a12682303f64.setContent(html_c46d9f92f3115ddf1985f7fded9041f9);
#
#
#
#         marker_599873212efecd3b05ed2687caa010cc.bindPopup(popup_ade876f984418285e719a12682303f64)
#         ;
#
#
#
#
#             var marker_310282a3f7906b4989f1f4fa75d757d6 = L.marker(
#                 [-0.22, -78.5125],
#                 {}
#             ).addTo(map_36613f96a9d2bc2a14cf82ba1b4ca997);
#
#
#         var popup_7aa113dbb9dc931eed6aea30608714b0 = L.p
